# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('Chest X-ray.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img
# Out:
# array([[[  9,   7,   7],
#         [  8,   6,   6],
#         [  8,   6,   6],
#         ...,
#         [ 30,  24,  11],
#         [ 26,  19,   2],
#         [100,  94,  71]],
#
#        [[  8,   6,   6],
#         [  8,   6,   6],
#         [  8,   6,   6],
#         ...,
#         [ 29,  23,  12],
#         [ 26,  19,   2],
#         [100,  93,  73]],
#
#        [[  8,   6,   6],
#         [  8,   6,   6],
#         [  8,   6,   6],
#         ...,
#         [ 29,  22,  13],
#         [ 25,  18,   3],
#         [ 99,  92,  72]],
#
#        ...,
#
#        [[  9,   7,   7],
#         [  8,   6,   6],
#         [  8,   6,   6],
#         ...,
#         [  9,   4,   3],
#         [  8,   4,   0],
#         [106,  98,  91]],
#
#        [[  8,   6,   6],
#         [  8,   6,   6],
#         [  8,   6,   6],
#         ...,
#         [  9,   4,   1],
#         [  8,   4,   0],
#         [106,  98,  91]],
#
#        [[  7,   5,   5],
#         [  7,   5,   5],
#         [  7,   5,   5],
#         ...,
#         [  9,   4,   1],
#         [  9,   5,   0],
#         [108, 100,  93]]], dtype=uint8)

# %% [markdown]
# Grayscale Conversion

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.title('Grayscale')
plt.show()

# %% [markdown]
# Histogram visualization
#
# Left:Dark, Right:Bright

# %%
plt.hist(gray.ravel(),bins=256,range=[0,256])
plt.title('Histogram of grayscale image')
plt.xlabel('Pixel intensity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Image resizing

# %%
resized = cv2.resize(gray,None, fx=0.75,fy=0.75)
plt.imshow(resized)
plt.title('Resized image')
plt.show()

# %%
edge = cv2.Canny(gray,100,200)
plt.imshow(edge, cmap = 'gray')
plt.title('Edge detection')
plt.show()

# %%
mean=0
sigma=25

gaussian = np.random.normal(mean,sigma,gray.shape)
noisy = gray+gaussian
noisy = np.clip(noisy,0,255).astype(np.uint8)
plt.imshow(noisy,cmap='gray')
plt.title('Gaussian noise')
plt.show()

# %%
denoised = cv2.GaussianBlur(noisy,(5,5),0)
plt.imshow(denoised,cmap='gray')
plt.title('Denoised')
plt.show()
